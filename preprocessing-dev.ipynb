# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from sklearn.utils import resample

# %%
df = pd.read_csv('dev_data.csv')

# %%
df
# Out:
#                Pid                                          text data  \
# 0        dev_pid_1  Im scared : This is it. I lie to myself every ...
# 1        dev_pid_2  New to this but just wanted to vent : I just f...
# 2        dev_pid_3  I’m sad : It’s kinda always been an issue. I w...
# 3        dev_pid_4  Lonely but not alone. : All of my immediately ...
# 4        dev_pid_5  This year has been trash. : I dont know why I’...
# ...            ...                                                ...
# 3240  dev_pid_3241  Feeling lonely. : Hi reddit, I haven’t posted ...
# 3241  dev_pid_3242  When would suicide be right? : So I got back f...
# 3242  dev_pid_3243  Lowest I’ve ever been ever. : To make a long s...
# 3243  dev_pid_3244  Does the Toxoplasma Gondii ruined my life ? (f...
# 3244  dev_pid_3245  Getting the correct diagnosis : Currently goin...
#
#      Class labels
# 0        moderate
# 1        moderate
# 2        moderate
# 3        moderate
# 4        moderate
# ...           ...
# 3240       severe
# 3241       severe
# 3242       severe
# 3243       severe
# 3244       severe
#
# [3245 rows x 3 columns]

# %%
df.dropna(inplace=True)

# %%
def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[@#]\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    tokens = nltk.word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    text = ' '.join(filtered_tokens)
    return text

df['text data'] = df['text data'].apply(preprocess_text)

# %%
df
# Out:
#                Pid                                          text data  \
# 0        dev_pid_1  im scared lie every day say ill make think mig...
# 1        dev_pid_2  new wanted vent finally realized im kind bad m...
# 2        dev_pid_3  im sad kinda always issue wouldnt say bad peer...
# 3        dev_pid_4  lonely alone immediately family members dead d...
# 4        dev_pid_5  year trash dont know im posting dont even know...
# ...            ...                                                ...
# 3240  dev_pid_3241  feeling lonely hi reddit havent posted sub har...
# 3241  dev_pid_3242  would suicide right got back hospital weeks ag...
# 3242  dev_pid_3243  lowest ive ever ever make long story short mad...
# 3243  dev_pid_3244  toxoplasma gondii ruined life first part ok go...
# 3244  dev_pid_3245  getting correct diagnosis currently going gett...
#
#      Class labels
# 0        moderate
# 1        moderate
# 2        moderate
# 3        moderate
# 4        moderate
# ...           ...
# 3240       severe
# 3241       severe
# 3242       severe
# 3243       severe
# 3244       severe
#
# [3245 rows x 3 columns]

# %%
df_minority1 = df[df['Class labels'] == 'severe']
df_minority2 = df[df['Class labels'] == 'not depression']
df_majority = df[df['Class labels'] == 'moderate']

# %%
df_minority1_upsampled = resample(df_minority1, replace=True, n_samples=len(df_majority), random_state=123)
df_minority2_upsampled = resample(df_minority2, replace=True, n_samples=len(df_majority), random_state=123)

# %%
df_upsampled = pd.concat([df_majority, df_minority1_upsampled, df_minority2_upsampled])

# %%
df_upsampled['Class labels'] = df_upsampled['Class labels']

# %%
df_upsampled
# Out:
#                Pid                                          text data  \
# 0        dev_pid_1  im scared lie every day say ill make think mig...
# 1        dev_pid_2  new wanted vent finally realized im kind bad m...
# 2        dev_pid_3  im sad kinda always issue wouldnt say bad peer...
# 3        dev_pid_4  lonely alone immediately family members dead d...
# 4        dev_pid_5  year trash dont know im posting dont even know...
# ...            ...                                                ...
# 2513  dev_pid_2514  anyone feared theyll kill loved ones sleep uni...
# 2828  dev_pid_2829  finally got fulltime job feel even worse maybe...
# 2259  dev_pid_2260  deal boredomnothing satisfying anymore days ta...
# 2652  dev_pid_2653                   got bed showered morning removed
# 2459  dev_pid_2460  depressed suicidal 2018 start 2020 ive woken d...
#
#         Class labels
# 0           moderate
# 1           moderate
# 2           moderate
# 3           moderate
# 4           moderate
# ...              ...
# 2513  not depression
# 2828  not depression
# 2259  not depression
# 2652  not depression
# 2459  not depression
#
# [6507 rows x 3 columns]

# %%
df_upsampled.to_csv('preprocessed_dev_data.csv', index=False)
